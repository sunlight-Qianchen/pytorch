# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import numpy as np
 
lst1 = [3.14, 2.17, 0, 1, 2]
nd1 =np.array(lst1)
nd1
# Out:
# array([3.14, 2.17, 0.  , 1.  , 2.  ])

# %%
type(nd1)
# Out:
# numpy.ndarray

# %%
import numpy as np

#生成10000个形状为2X3的矩阵
data_train = np.random.randn(10000,2,3)

# %%
#这是一个3维矩阵，第一个维度为样本数，后两个是数据形状
data_train.shape
# Out:
# (10000, 2, 3)

# %%
#打乱这10000条数据
np.random.shuffle(data_train)

#定义批量大小
batch_size=100

#进行批处理
for i in range(0,len(data_train),batch_size):
    x_batch_sum=np.sum(data_train[i:i+batch_size])
    print("第{}批次,该批次的数据之和:{}".format(i,x_batch_sum))
# Out:
# 第0批次,该批次的数据之和:-50.265355480105214
# 第100批次,该批次的数据之和:37.66064817480904
# 第200批次,该批次的数据之和:8.48658823780368
# 第300批次,该批次的数据之和:30.220074784944263
# 第400批次,该批次的数据之和:-11.530062723605933
# 第500批次,该批次的数据之和:-1.351571126461966
# 第600批次,该批次的数据之和:4.467581354465444
# 第700批次,该批次的数据之和:6.444827676426293
# 第800批次,该批次的数据之和:-26.981939823006932
# 第900批次,该批次的数据之和:8.622315584780832
# 第1000批次,该批次的数据之和:-11.914111038846684
# 第1100批次,该批次的数据之和:25.23626140217658
# 第1200批次,该批次的数据之和:-17.015577536178
# 第1300批次,该批次的数据之和:41.069713850138115
# 第1400批次,该批次的数据之和:38.62946563658846
# 第1500批次,该批次的数据之和:18.27437826000984
# 第1600批次,该批次的数据之和:29.89379641622543
# 第1700批次,该批次的数据之和:13.424200582949982
# 第1800批次,该批次的数据之和:11.932961601193663
# 第1900批次,该批次的数据之和:-4.007466522780488
# 第2000批次,该批次的数据之和:7.4032076871819985
# 第2100批次,该批次的数据之和:-31.371907341639748
# 第2200批次,该批次的数据之和:-29.026342424969194
# 第2300批次,该批次的数据之和:11.704410918011932
# 第2400批次,该批次的数据之和:-29.904749168113177
# 第2500批次,该批次的数据之和:19.10839386627079
# 第2600批次,该批次的数据之和:38.147642469933174
# 第2700批次,该批次的数据之和:-1.4877906546865667
# 第2800批次,该批次的数据之和:-15.266730548245025
# 第2900批次,该批次的数据之和:-38.8070453451093
# 第3000批次,该批次的数据之和:-24.24309862494374
# 第3100批次,该批次的数据之和:-7.37773867729873
# 第3200批次,该批次的数据之和:15.527354655966832
# 第3300批次,该批次的数据之和:13.643057679938146
# 第3400批次,该批次的数据之和:-23.488856996402124
# 第3500批次,该批次的数据之和:-5.321602137902255
# 第3600批次,该批次的数据之和:35.89256975357095
# 第3700批次,该批次的数据之和:-62.5908996603662
# 第3800批次,该批次的数据之和:-7.41589282031539
# 第3900批次,该批次的数据之和:-2.208257245768533
# 第4000批次,该批次的数据之和:42.79550623259523
# 第4100批次,该批次的数据之和:2.202284531306323
# 第4200批次,该批次的数据之和:19.767299613135513
# 第4300批次,该批次的数据之和:3.894849805051635
# 第4400批次,该批次的数据之和:-6.1729447246106375
# 第4500批次,该批次的数据之和:-36.81076889014352
# 第4600批次,该批次的数据之和:-7.906838640416765
# 第4700批次,该批次的数据之和:-8.80896141471291
# 第4800批次,该批次的数据之和:1.7531295934636555
# 第4900批次,该批次的数据之和:19.608274475286194
# 第5000批次,该批次的数据之和:1.7219662621767622
# 第5100批次,该批次的数据之和:-31.966181995698182
# 第5200批次,该批次的数据之和:-30.10795301128752
# 第5300批次,该批次的数据之和:-10.674571205315548
# 第5400批次,该批次的数据之和:24.727204309953095
# 第5500批次,该批次的数据之和:14.740857647672165
# 第5600批次,该批次的数据之和:34.54343537774558
# 第5700批次,该批次的数据之和:44.131979655144626
# 第5800批次,该批次的数据之和:11.047188847270462
# 第5900批次,该批次的数据之和:12.417879489316682
# 第6000批次,该批次的数据之和:0.7909284048918543
# 第6100批次,该批次的数据之和:-8.446777976426409
# 第6200批次,该批次的数据之和:-3.627199822196978
# 第6300批次,该批次的数据之和:-8.7459750832151
# 第6400批次,该批次的数据之和:-39.18563852605173
# 第6500批次,该批次的数据之和:-0.8965160314992922
# 第6600批次,该批次的数据之和:-5.0661935896186066
# 第6700批次,该批次的数据之和:-11.66915382765405
# 第6800批次,该批次的数据之和:9.87442968555756
# 第6900批次,该批次的数据之和:-6.656046001728065
# 第7000批次,该批次的数据之和:-8.064173607665044
# 第7100批次,该批次的数据之和:-0.3254480401984452
# 第7200批次,该批次的数据之和:1.2583361258523662
# 第7300批次,该批次的数据之和:-2.748203707002901
# 第7400批次,该批次的数据之和:1.2206158864528103
# 第7500批次,该批次的数据之和:46.10103709792618
# 第7600批次,该批次的数据之和:-19.13329103360353
# 第7700批次,该批次的数据之和:30.428183057864267
# 第7800批次,该批次的数据之和:23.807358209478082
# 第7900批次,该批次的数据之和:-1.5822691139230765
# 第8000批次,该批次的数据之和:10.909739809543924
# 第8100批次,该批次的数据之和:18.65369327790038
# 第8200批次,该批次的数据之和:5.800149423204471
# 第8300批次,该批次的数据之和:-6.308744958243903
# 第8400批次,该批次的数据之和:7.171730650319025
# 第8500批次,该批次的数据之和:-17.31694575573949
# 第8600批次,该批次的数据之和:-14.045744618086557
# 第8700批次,该批次的数据之和:-1.9718540449137176
# 第8800批次,该批次的数据之和:-50.608300969273365
# 第8900批次,该批次的数据之和:-22.064450399203736
# 第9000批次,该批次的数据之和:35.94706232411075
# 第9100批次,该批次的数据之和:4.456994054678464
# 第9200批次,该批次的数据之和:5.95251114488584
# 第9300批次,该批次的数据之和:-6.27613275017611
# 第9400批次,该批次的数据之和:-43.194481515138904
# 第9500批次,该批次的数据之和:-3.59218245668176
# 第9600批次,该批次的数据之和:-38.49320186515119
# 第9700批次,该批次的数据之和:-17.208783337211045
# 第9800批次,该批次的数据之和:-3.786819287183107
# 第9900批次,该批次的数据之和:-18.85452105725524
